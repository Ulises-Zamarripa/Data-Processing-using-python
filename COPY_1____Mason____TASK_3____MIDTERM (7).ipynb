# %%
# Midterm Project- Step 3, Part 1: Before Data Cleanup
# Hotel Booking Dataset Before Data Processing
# By: Cristopher Cequea-Rivero

# Import Required Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load Dataset
file_path = 'hotel_bookings.csv'
df = pd.read_csv(file_path)

# Display Basic Info
print("Dataset Shape:", df.shape)
print("\nColumn Names:\n", df.columns.tolist())

# Preview the Data
print("\nFirst 5 Rows:")
display(df.head())

# Data Types and Non-Null Counts
print("\nDataset Info:")
df.info()

# Basic Statistics
print("\nStatistical Summary (Numerical Columns):")
display(df.describe())

# Check for Missing Values
print("\nMissing Values Per Column:")
missing = df.isnull().sum().sort_values(ascending=False)
display(missing[missing > 0])

# Visualize Missing Data
plt.figure(figsize=(12,6))
sns.heatmap(df.isnull(), cbar=False)
plt.title('Missing Data Heatmap - Before Cleanup')
plt.show()

# Unique Value Counts for Categorical Features
cat_cols = df.select_dtypes(include=['object']).columns
print(f"\nNumber of Categorical Columns: {len(cat_cols)}")
for col in cat_cols[:10]:
    print(f"\nColumn: {col}")
    print(df[col].value_counts().head())

# Correlation Matrix for Numerical Columns
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(numeric_only=True), cmap='coolwarm', annot=False)
plt.title('Correlation Matrix (Before Processing)')
plt.show()

# Observations:
# 1. The dataset contains both numerical and categorical variables (mix of reservation and guest data).
# 2. Some columns show missing values (e.g., company, agent, children, country, etc.).
# 3. The 'is_canceled' column appears to be the target variable for predicting cancellations.
# 4. The data will require feature engineering, encoding, and normalization for machine learning readiness.

# Next Steps (to be shown in the 'After Data Processing' notebook):
# Handle missing values appropriately.
# Encode categorical variables using One-Hot or Label Encoding.
# Scale and normalize numerical features.
# Prepare the dataset for model training.
# Out:
# Dataset Shape: (119390, 32)
#
# Column Names:
#  ['hotel', 'is_canceled', 'lead_time', 'arrival_date_year', 'arrival_date_month', 'arrival_date_week_number', 'arrival_date_day_of_month', 'stays_in_weekend_nights', 'stays_in_week_nights', 'adults', 'children', 'babies', 'meal', 'country', 'market_segment', 'distribution_channel', 'is_repeated_guest', 'previous_cancellations', 'previous_bookings_not_canceled', 'reserved_room_type', 'assigned_room_type', 'booking_changes', 'deposit_type', 'agent', 'company', 'days_in_waiting_list', 'customer_type', 'adr', 'required_car_parking_spaces', 'total_of_special_requests', 'reservation_status', 'reservation_status_date']
#
# First 5 Rows:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# ...

# %%
#Mason
#First step of Data Cleaning
#Load in Columns, Look at columns, and find what is redundant information
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
#Mason
#Drop Unneeded columns
#Required Car Parking Spaces doesn't effect the Is Cancelled in a meaningful way
#Dropping required_car_parking_spaces
#Axis=0 drops rows, Axis=1 drops columns
#Added if statement because it causes errors if you run it more than once, because it is already deleted (if you run it without the if statement)
if 'required_car_parking_spaces' in df.columns:
  df = df.drop('required_car_parking_spaces', axis=1)

# %%
#Mason
#Rename columns to more accurately represent what the data is showing
#Renaming adults, children, and babies to number of adults,children, and babies respectively
df.rename ({'adults' : 'num_adults' , 'children' : 'num_children', 'babies' : 'num_babies'}, axis=1, inplace=True)

# %%
#Mason
#Check the data to ensure dropped and renamed have run successfully
#Everything looks correct
#Some columns weren't showing, added to display every single column to check if previous code ran correctly
pd.set_option('display.max_columns', None)
df.head(3)
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  num_adults  num_children  \
# 0                        0                     0           2           0.0
# 1                        0                     0           2           0.0
# 2                        0                     1           1           0.0
#
#    num_babies meal country market_segment distribution_channel  \
# ...

# %%
#Mason
#Check the data to ensure dropped and renamed have run successfully
#Everything looks correct
#Some columns weren't showing, added to display every single column to check if previous code ran correctly
pd.set_option('display.max_columns', None)
df.head(3)
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  num_adults  num_children  \
# 0                        0                     0           2           0.0
# 1                        0                     0           2           0.0
# 2                        0                     1           1           0.0
#
#    num_babies meal country market_segment distribution_channel  \
# ...

# %%
#Mason
#Check the data to ensure dropped and renamed have run successfully
#Some columns weren't showing, added to display every single column to check if previous code ran correctly
#Everything looks correct
pd.set_option('display.max_columns', None)
df.head(1)
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  num_adults  num_children  \
# 0                        0                     0           2           0.0
#
#    num_babies meal country market_segment distribution_channel  \
# 0           0   BB     PRT         Direct               Direct
#
#    is_repeated_guest  previous_cancellations  previous_bookings_not_canceled  \
# 0                  0                       0                               0
#
#   reserved_room_type assigned_room_type  booking_changes deposit_type  agent  \
# 0                  C                  C                3   No Deposit    NaN
#
#    company  days_in_waiting_list customer_type  adr  \
# ...

# %%
#Mason
#Checking how many Nan/Null values in each column
# Multiplied by 100 divided by total length of dataset,to show what percentage of each column has Nan/Null values
df.isnull().sum() * 100 / len(df)
# Out:
# hotel                              0.000000
# is_canceled                        0.000000
# lead_time                          0.000000
# arrival_date_year                  0.000000
# arrival_date_month                 0.000000
# arrival_date_week_number           0.000000
# arrival_date_day_of_month          0.000000
# stays_in_weekend_nights            0.000000
# stays_in_week_nights               0.000000
# num_adults                         0.000000
# num_children                       0.003350
# num_babies                         0.000000
# meal                               0.000000
# country                            0.408744
# market_segment                     0.000000
# distribution_channel               0.000000
# is_repeated_guest                  0.000000
# previous_cancellations             0.000000
# previous_bookings_not_canceled     0.000000
# reserved_room_type                 0.000000
# assigned_room_type                 0.000000
# ...

# %%
#Mason
# Column Company has 94% Nan/Null values
# Dropping because it doesn't have much relevant info
df.drop('company' , axis=1)
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
#Mason


#Really not sure if this is the best way to do this (TO SKYNET GROUP)
#-1 signifies missing data in general with Machine Learning, without deleting every row with a missing value, so I replaced it to -1 (TO SKYNET GROUP)


#Agent Column has quite a few Nan/Null but is mostly good info
#Fill all Nan/Null values in Agent Column with -1
df['agent'].fillna(-1)
# Out:
# 0          -1.0
# 1          -1.0
# 2          -1.0
# 3         304.0
# 4         240.0
#           ...
# 119385    394.0
# 119386      9.0
# 119387      9.0
# 119388     89.0
# 119389      9.0
# Name: agent, Length: 119390, dtype: float64
